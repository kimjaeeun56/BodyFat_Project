# %% [markdown]
# # 한글깨짐

# %%
# 단계 1: 폰트 설치
import matplotlib.font_manager as fm

# !apt-get -qq -y install fonts-nanum > /dev/null
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
fm._rebuild()

# %%
# 단계 2: 런타임 재시작
import os
os.kill(os.getpid(), 9)

# %%
# 단계 3: 한글 폰트 설정
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.font_manager as fm

# 마이너스 표시 문제
mpl.rcParams['axes.unicode_minus'] = False
	
# 한글 폰트 설정
path = '/usr/share/fonts/truetype/nanum/NanumGothicBold.ttf'
font_name = fm.FontProperties(fname=path, size=18).get_name()
plt.rc('font', family=font_name)
fm._rebuild()

# %% [markdown]
# # 1. 환경설정

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)
pd.options.display.float_format = '{:.2f}'.format

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd '/content/gdrive/MyDrive/sbs/핵심역량프로젝트/그래프'
# !ls
# Out:
# /content/gdrive/.shortcut-targets-by-id/13UT7pZKq5f5I3_As8dIyogN3Up9BH8R9/00_sbs/핵심역량프로젝트/그래프
# '전체 상위체력인구 비중 변화.csv'  '년도별 체지방률 등급(수).csv'
#  노인_여자.csv			   '년도별 체지방률 등급(비율).csv'
#  노인_남자.csv			    청소년_여자.csv
#  노인_근력.csv			    청소년_남자.csv
#  노인_체지방률.csv		    청소년_근력.csv
#  노인_심폐지구력.csv		    청소년_체지방률.csv
#  노인.csv			    청소년_심폐지구력.csv
#  근력_여자_비교.csv		    청소년.csv
#  성인_여자.csv			    체지방률_여자_비교.csv
#  근력_남자_비교.csv		    체지방률_남자_비교.csv
#  성인_남자.csv			   '연령대별 상위체력인구 비중 변화.csv'
#  성인_근력.csv			    심폐지구력_여자_비교.csv
#  성인_체지방률.csv		    심폐지구력_남자_비교.csv
#  성인_심폐지구력.csv		    그래프.ipynb
#  성인.csv			   '상위체력인구 비중.png'

# %% [markdown]
# # 그래프

# %% [markdown]
# ## 1. 심폐지구력 2019/2021 비교(남녀)

# %%
m_run_df = pd.read_csv('/content/gdrive/MyDrive/sbs/핵심역량프로젝트/그래프/심폐지구력_남자_비교.csv')
f_run_df = pd.read_csv('/content/gdrive/MyDrive/sbs/핵심역량프로젝트/그래프/심폐지구력_여자_비교.csv')

# %%
m_run_df = m_run_df.set_index('측정년도')
f_run_df = f_run_df.set_index('측정년도')

# %%
# # 심폐지구력_남자_비교.csv , 심폐지구력_여자_비교.csv
fig = plt.figure(figsize=(28,8))
plt.style.use('ggplot')
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

m_run_df.plot(ax=ax1, kind='bar',  title="심폐지구력 비교(남)", rot=0, color=['#ff9999', '#ffc000', '#8fd9b6'])
f_run_df.plot(ax=ax2, kind='bar',  title="심폐지구력 비교(여)", rot=0, color=['#ff9999', '#ffc000', '#8fd9b6'])
ax1.legend(m_run_df.columns, loc='best')
ax2.legend(f_run_df.columns, loc='best')

for patch in ax1.patches:
    ax1.text(x = patch.get_x() + patch.get_width()/2, 
             y = patch.get_height() + len(m_run_df)*0.2,
             s = f'{patch.get_height():.1f}회',
             ha = 'center')
    
for patch in ax2.patches:
    ax2.text(x = patch.get_x() + patch.get_width()/2, 
             y = patch.get_height() + len(f_run_df)*0.2,
             s = f'{patch.get_height():.1f}회',
             ha = 'center')

'''
for p in ax1.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax1.annotate("%.1f 회"%(height/1e6), (left+width/2, height*1.01), ha='center')

for p in ax2.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax2.annotate("%.1f 회"%(height/1e6), (left+width/2, height*1.01), ha='center')

plt.savefig('심폐지구력 전후(남/여).png', bbox_inches='tight', pad_inches=0.5)
'''

plt.show()

# %% [markdown]
# ## 2. 근력 2019/2021 비교(남녀)

# %%
m_grip_df = pd.read_csv('/content/gdrive/MyDrive/sbs/핵심역량프로젝트/그래프/근력_남자_비교.csv')
f_grip_df = pd.read_csv('/content/gdrive/MyDrive/sbs/핵심역량프로젝트/그래프/근력_여자_비교.csv')

# %%
m_grip_df = m_grip_df.set_index('측정년도')
f_grip_df = f_grip_df.set_index('측정년도')

# %%
# 근력_남자_비교.csv , 근력_여자_비교.csv
fig = plt.figure(figsize=(28,8))
plt.style.use('ggplot')
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

m_grip_df.plot(ax=ax1, kind='bar',  title="근력 비교(남)", rot=0, color=['#ff9999', '#ffc000', '#8fd9b6'])
f_grip_df.plot(ax=ax2, kind='bar',  title="근력 비교(여)", rot=0, color=['#ff9999', '#ffc000', '#8fd9b6'])
ax1.legend(m_grip_df.columns, loc='best')
ax2.legend(f_grip_df.columns, loc='best')

for patch in ax1.patches:
    ax1.text(x = patch.get_x() + patch.get_width()/2, 
             y = patch.get_height() + len(m_grip_df)*0.2,
             s = f'{patch.get_height():.1f}회',
             ha = 'center')
    
for patch in ax2.patches:
    ax2.text(x = patch.get_x() + patch.get_width()/2, 
             y = patch.get_height() + len(f_grip_df)*0.2,
             s = f'{patch.get_height():.1f}회',
             ha = 'center')

'''
for p in ax1.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax1.annotate("%.1f %%"%(height/1e6), (left+width/2, height*1.01), ha='center')

for p in ax2.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax2.annotate("%.1f %%"%(height/1e6), (left+width/2, height*1.01), ha='center')
'''

# plt.savefig('근력 전후(남/여).png', bbox_inches='tight', pad_inches=0.5)
plt.show()

# %% [markdown]
# ## 3. 체지방률 2019/2021 비교(남녀)

# %%
m_fat_df = pd.read_csv('/content/gdrive/MyDrive/sbs/핵심역량프로젝트/그래프/체지방률_남자_비교.csv')
f_fat_df = pd.read_csv('/content/gdrive/MyDrive/sbs/핵심역량프로젝트/그래프/체지방률_여자_비교.csv')

# %%
m_fat_df = m_fat_df.set_index('측정년도')
f_fat_df = f_fat_df.set_index('측정년도')

# %%
# 체지방률_남자_비교.csv , 체지방률_여자_비교.csv
fig = plt.figure(figsize=(28,8))
plt.style.use('ggplot')
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

m_fat_df.plot(ax=ax1, kind='bar',  title="체지방률 비교(남)", rot=0, color=['#ff9999', '#ffc000', '#8fd9b6'])
f_fat_df.plot(ax=ax2, kind='bar',  title="체지방률 비교(여)", rot=0, color=['#ff9999', '#ffc000', '#8fd9b6'])
ax1.legend(m_fat_df.columns, loc='best')
ax2.legend(f_fat_df.columns, loc='best')

for patch in ax1.patches:
    ax1.text(x = patch.get_x() + patch.get_width()/2, 
             y = patch.get_height() + len(m_fat_df)*0.2,
             s = f'{patch.get_height():.1f}%',
             ha = 'center')
    
for patch in ax2.patches:
    ax2.text(x = patch.get_x() + patch.get_width()/2, 
             y = patch.get_height() + len(f_fat_df)*0.2,
             s = f'{patch.get_height():.1f}%',
             ha = 'center')

'''
for p in ax1.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax1.annotate("%.1f %%"%(height/1e6), (left+width/2, height*1.01), ha='center')

for p in ax2.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax2.annotate("%.1f %%"%(height/1e6), (left+width/2, height*1.01), ha='center')
'''

# plt.savefig('체지방률 전후(남/여).png', bbox_inches='tight', pad_inches=0.5)
plt.show()

# %% [markdown]
# ## 4. 심폐지구력 2019/2021 비교(연령대)

# %%
teen_run_graph = pd.read_csv('/content/gdrive/MyDrive/sbs/핵심역량프로젝트/그래프/청소년_심폐지구력.csv')
adult_run_graph = pd.read_csv('/content/gdrive/MyDrive/sbs/핵심역량프로젝트/그래프/성인_심폐지구력.csv')
old_run_graph = pd.read_csv('/content/gdrive/MyDrive/sbs/핵심역량프로젝트/그래프/노인_심폐지구력.csv')

# %%
teen_run_graph = teen_run_graph.rename(index={0:2019, 1:2021})
adult_run_graph = adult_run_graph.rename(index={0:2019, 1:2021})
old_run_graph = old_run_graph.rename(index={0:2019, 1:2021})

# %%
# 청소년 심폐지구력 변화
plt.figure(figsize=(15,15))
plt.style.use('ggplot')

plt.rc('font', size=15)        # 기본 폰트 크기
plt.rc('axes', labelsize=30)   # x,y축 label 폰트 크기
plt.rc('xtick', labelsize=20)  # x축 눈금 폰트 크기 
plt.rc('ytick', labelsize=20)  # y축 눈금 폰트 크기
plt.rc('figure', titlesize=20) # figure title 폰트 크기

ax = teen_run_graph.plot(kind='bar',  title="심폐지구력 청소년 변화", rot=0, color=['#ff9999', '#ffc000', '#8fd9b6'], figsize=(10,11))
ax.legend(teen_run_graph.columns, loc='best')

for patch in ax.patches:
    ax.text(x = patch.get_x() + patch.get_width()/2, 
             y = patch.get_height() + len(teen_run_graph)*0.2,
             s = f'{patch.get_height():.1f}회',
             ha = 'center')

plt.show()

# %%
# 성인 심폐지구력 변화
plt.figure(figsize=(10,11))
plt.style.use('ggplot')

plt.rc('font', size=15)        # 기본 폰트 크기
plt.rc('axes', labelsize=30)   # x,y축 label 폰트 크기
plt.rc('xtick', labelsize=20)  # x축 눈금 폰트 크기 
plt.rc('ytick', labelsize=20)  # y축 눈금 폰트 크기
plt.rc('figure', titlesize=20) # figure title 폰트 크기

ax = adult_run_graph.plot(kind='bar',  title="심폐지구력 성인 변화", rot=0, color=['#ff9999', '#ffc000', '#8fd9b6'], figsize=(10,11))
ax.legend(adult_run_graph.columns, loc='best')

for patch in ax.patches:
    ax.text(x = patch.get_x() + patch.get_width()/2, 
             y = patch.get_height() + len(teen_run_graph)*0.2,
             s = f'{patch.get_height():.1f}회',
             ha = 'center')

plt.show()

# %%
# 노인 심폐지구력 변화
plt.figure(figsize=(10,11))
plt.style.use('ggplot')

plt.rc('font', size=15)        # 기본 폰트 크기
plt.rc('axes', labelsize=30)   # x,y축 label 폰트 크기
plt.rc('xtick', labelsize=20)  # x축 눈금 폰트 크기 
plt.rc('ytick', labelsize=20)  # y축 눈금 폰트 크기
plt.rc('figure', titlesize=20) # figure title 폰트 크기

ax = old_run_graph.plot(kind='bar',  title="심폐지구력 노인 변화", rot=0, color=['#ff9999', '#ffc000', '#8fd9b6'], figsize=(12,12))
ax.legend(old_run_graph.columns, loc='upper right')

for patch in ax.patches:
    ax.text(x = patch.get_x() + patch.get_width()/2, 
             y = patch.get_height() + len(teen_run_graph)*0.2,
             s = f'{patch.get_height():.1f}회',
             ha = 'center')

plt.show()

# %%
# 심폐지구력(청소년_심폐지구력.csv, 성인_심폐지구력.csv, 노인_심폐지구력.csv)
fig = plt.figure(figsize=(28,8))
plt.style.use('ggplot')
ax1 = fig.add_subplot(1,3,1)
ax2 = fig.add_subplot(1,3,2)
ax3 = fig.add_subplot(1,3,3)

teen_run_graph.plot(ax=ax1, kind='bar',  title="심폐지구력 청소년 변화", rot=0, color=['#ff9999', '#ffc000', '#8fd9b6'])
adult_run_graph.plot(ax=ax2, kind='bar',  title="심폐지구력 성인 변화", rot=0, color=['#ff9999', '#ffc000', '#8fd9b6'])
old_run_graph.plot(ax=ax3, kind='bar',  title="심폐지구력 노인 변화", rot=0, color=['#ff9999', '#ffc000', '#8fd9b6'])

ax1.legend(teen_run_graph.columns, loc='best')
ax2.legend(adult_run_graph.columns, loc='best')
ax3.legend(old_run_graph.columns, loc='best')

for patch in ax1.patches:
    ax1.text(x = patch.get_x() + patch.get_width()/2, 
             y = patch.get_height() + len(teen_run_graph)*0.2,
             s = f'{patch.get_height():.1f}회',
             ha = 'center')
    
for patch in ax2.patches:
    ax2.text(x = patch.get_x() + patch.get_width()/2, 
             y = patch.get_height() + len(adult_run_graph)*0.2,
             s = f'{patch.get_height():.1f}회',
             ha = 'center')
    
for patch in ax3.patches:
    ax3.text(x = patch.get_x() + patch.get_width()/2, 
             y = patch.get_height() + len(old_run_graph)*0.2,
             s = f'{patch.get_height():.1f}회',
             ha = 'center')

'''
for p in ax1.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax1.annotate("%.1f 회"%(height/1e6), (left+width/2, height*1.01), ha='center')

for p in ax2.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax2.annotate("%.1f 회"%(height/1e6), (left+width/2, height*1.01), ha='center')

for p in ax3.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax3.annotate("%.1f 회"%(height/1e6), (left+width/2, height*1.01), ha='center')
'''

# plt.savefig('심폐지구력 전후(청소년/성인/노인).png', bbox_inches='tight', pad_inches=0.5)
plt.show()

# %% [markdown]
# 어진님 코드

# %%
# 심폐지구력(청소년_심폐지구력.csv, 성인_심폐지구력.csv, 노인_심폐지구력.csv)
fig = plt.figure(figsize=(28,8))
plt.style.use('ggplot')
ax1 = fig.add_subplot(1,3,1)
ax2 = fig.add_subplot(1,3,2)
ax3 = fig.add_subplot(1,3,3)

teen_run_graph.plot(ax=ax1, kind='bar',  title="심폐지구력 청소년 변화", rot=0, color=['#FF9999', '#FFC000', '#8FD9B6'])
adult_run_graph.plot(ax=ax2, kind='bar',  title="심폐지구력 성인 변화", rot=0, color=['#FF9999', '#FFC000', '#8FD9B6'])
old_run_graph.plot(ax=ax3, kind='bar',  title="심폐지구력 노인 변화", rot=0, color=['#FF9999', '#FFC000', '#8FD9B6'])
ax1.legend(teen_run_graph.columns, loc='best')
ax2.legend(adult_run_graph.columns, loc='best')
ax3.legend(old_run_graph.columns, loc='best')

for p in ax1.patches:
    left, bottom, width, height = p.get_bbox().bounds
ax1.annotate("%.1f 회"%(teen_run_graph.iloc[0, 0]), (left-width*4.5, height*2.08), ha='center')
ax1.annotate("%.1f 회"%(teen_run_graph.iloc[0, 1]), (left-width*3.5, height*1.2), ha='center')
ax1.annotate("%.1f 회"%(teen_run_graph.iloc[1, 0]), (left-width/2, height*1.86), ha='center')
ax1.annotate("%.1f 회"%(teen_run_graph.iloc[1, 1]), (left+width/2, height*1.01), ha='center')

for p in ax2.patches:
    left, bottom, width, height = p.get_bbox().bounds
ax2.annotate("%.1f 회"%(adult_run_graph.iloc[0, 0]), (left-width*4.5, height*1.5), ha='center')
ax2.annotate("%.1f 회"%(adult_run_graph.iloc[0, 1]), (left-width*3.5, height*0.7), ha='center')
ax2.annotate("%.1f 회"%(adult_run_graph.iloc[1, 0]), (left-width/2, height*1.7), ha='center')
ax2.annotate("%.1f 회"%(adult_run_graph.iloc[1, 1]), (left+width/2, height*1.01), ha='center')

for p in ax3.patches:
    left, bottom, width, height = p.get_bbox().bounds
ax3.annotate("%.1f 회"%(old_run_graph.iloc[0, 0]), (left-width*4.5, height*1.03), ha='center')
ax3.annotate("%.1f 회"%(old_run_graph.iloc[0, 1]), (left-width*3.5, height*1), ha='center')
ax3.annotate("%.1f 회"%(old_run_graph.iloc[1, 0]), (left-width/2, height*1.05), ha='center')
ax3.annotate("%.1f 회"%(old_run_graph.iloc[1, 1]), (left+width/2, height*1.01), ha='center')

# plt.savefig('심폐지구력 전후(청소년/성인/노인).png', bbox_inches='tight', pad_inches=0.5)
plt.show()

# %% [markdown]
# ## 5. 근력 2019/2021 비교(연령대)

# %%
teen_grip_graph = pd.read_csv('/content/gdrive/MyDrive/sbs/핵심역량프로젝트/그래프/청소년_근력.csv')
adult_grip_graph = pd.read_csv('/content/gdrive/MyDrive/sbs/핵심역량프로젝트/그래프/성인_근력.csv')
old_grip_graph = pd.read_csv('/content/gdrive/MyDrive/sbs/핵심역량프로젝트/그래프/노인_근력.csv')

# %%
teen_grip_graph = teen_grip_graph.rename(index={0:2019, 1:2021})
adult_grip_graph = adult_grip_graph.rename(index={0:2019, 1:2021})
old_grip_graph = old_grip_graph.rename(index={0:2019, 1:2021})

# %%
# 근력(청소년_근력.csv, 성인_근력.csv, 노인_근력.csv)
fig = plt.figure(figsize=(28,8))
plt.style.use('ggplot')
ax1 = fig.add_subplot(1,3,1)
ax2 = fig.add_subplot(1,3,2)
ax3 = fig.add_subplot(1,3,3)

teen_grip_graph.plot(ax=ax1, kind='bar',  title="근력 청소년 변화", rot=0, color=['#ff9999', '#ffc000', '#8fd9b6'])
adult_grip_graph.plot(ax=ax2, kind='bar',  title="근력 성인 변화", rot=0, color=['#ff9999', '#ffc000', '#8fd9b6'])
old_grip_graph.plot(ax=ax3, kind='bar',  title="근력 노인 변화", rot=0, color=['#ff9999', '#ffc000', '#8fd9b6'])

ax1.legend(teen_grip_graph.columns, loc='best')
ax2.legend(adult_grip_graph.columns, loc='best')
ax3.legend(old_grip_graph.columns, loc='best')

for patch in ax1.patches:
    ax1.text(x = patch.get_x() + patch.get_width()/2, 
             y = patch.get_height() + len(teen_grip_graph)*0.2,
             s = f'{patch.get_height():.1f}회',
             ha = 'center')
    
for patch in ax2.patches:
    ax2.text(x = patch.get_x() + patch.get_width()/2, 
             y = patch.get_height() + len(adult_grip_graph)*0.2,
             s = f'{patch.get_height():.1f}회',
             ha = 'center')
    
for patch in ax3.patches:
    ax3.text(x = patch.get_x() + patch.get_width()/2, 
             y = patch.get_height() + len(old_grip_graph)*0.2,
             s = f'{patch.get_height():.1f}회',
             ha = 'center')

'''
for p in ax1.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax1.annotate("%.1f 회"%(height/1e6), (left+width/2, height*1.01), ha='center')

for p in ax2.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax2.annotate("%.1f 회"%(height/1e6), (left+width/2, height*1.01), ha='center')

for p in ax3.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax3.annotate("%.1f 회"%(height/1e6), (left+width/2, height*1.01), ha='center')
'''

# plt.savefig('근력 전후(청소년/성인/노인).png', bbox_inches='tight', pad_inches=0.5)
plt.show()

# %% [markdown]
# ## 6. 체지방률 2019/2021 비교(연령대)

# %%
teen_fat_graph = pd.read_csv('/content/gdrive/MyDrive/sbs/핵심역량프로젝트/그래프/청소년_체지방률.csv')
adult_fat_graph = pd.read_csv('/content/gdrive/MyDrive/sbs/핵심역량프로젝트/그래프/성인_체지방률.csv')
old_fat_graph = pd.read_csv('/content/gdrive/MyDrive/sbs/핵심역량프로젝트/그래프/노인_체지방률.csv')

teen_fat_graph = teen_fat_graph.rename(index={0:2019, 1:2021})
adult_fat_graph = adult_fat_graph.rename(index={0:2019, 1:2021})
old_fat_graph = old_fat_graph.rename(index={0:2019, 1:2021})

# %%
# 체지방률(청소년_체지방률.csv, 성인_체지방률.csv, 노인_체지방률.csv)
fig = plt.figure(figsize=(28,8))
plt.style.use('ggplot')
ax1 = fig.add_subplot(1,3,1)
ax2 = fig.add_subplot(1,3,2)
ax3 = fig.add_subplot(1,3,3)

teen_fat_graph.plot(ax=ax1, kind='bar',  title="체지방률 청소년 변화", rot=0, color=['#ff9999', '#ffc000', '#8fd9b6'])
adult_fat_graph.plot(ax=ax2, kind='bar',  title="체지방률 성인 변화", rot=0, color=['#ff9999', '#ffc000', '#8fd9b6'])
old_fat_graph.plot(ax=ax3, kind='bar',  title="체지방률 노인 변화", rot=0, color=['#ff9999', '#ffc000', '#8fd9b6'])
ax1.legend(teen_fat_graph.columns, loc='best')
ax2.legend(adult_fat_graph.columns, loc='best')
ax3.legend(old_fat_graph.columns, loc='best')

for patch in ax1.patches:
    ax1.text(x = patch.get_x() + patch.get_width()/2, 
             y = patch.get_height() + len(teen_fat_graph)*0.2,
             s = f'{patch.get_height():.1f}%',
             ha = 'center')
    
for patch in ax2.patches:
    ax2.text(x = patch.get_x() + patch.get_width()/2, 
             y = patch.get_height() + len(adult_fat_graph)*0.2,
             s = f'{patch.get_height():.1f}%',
             ha = 'center')
    
for patch in ax3.patches:
    ax3.text(x = patch.get_x() + patch.get_width()/2, 
             y = patch.get_height() + len(old_fat_graph)*0.2,
             s = f'{patch.get_height():.1f}%',
             ha = 'center')

'''
for p in ax1.patches:
    ax1.annotate('%.1f 회' % p.get_height(), (p.get_x() + p.get_width()/2., p.get_height() - 30),
                ha='center', va='center', fontsize=12, color='black', xytext=(0,10), textcoords='offset points')
for p in ax2.patches:
    ax2.annotate('%.1f 회' % p.get_height(), (p.get_x() + p.get_width()/2., p.get_height() - 30),
                ha='center', va='center', fontsize=12, color='black', xytext=(0,10), textcoords='offset points')
for p in ax3.patches:
    ax3.annotate('%.1f 회' % p.get_height(), (p.get_x() + p.get_width()/2., p.get_height() - 30),
                ha='center', va='center', fontsize=12, color='black', xytext=(0,10), textcoords='offset points')
'''

# plt.savefig('체지방률 전후(청소년/성인/노인).png', bbox_inches='tight', pad_inches=0.5)
plt.show()

# %% [markdown]
# ## 7. 심폐지구력 2019/2021 비교(연령대)

# %%
teen = pd.read_csv('/content/gdrive/MyDrive/sbs/핵심역량프로젝트/그래프/청소년.csv')
adult = pd.read_csv('/content/gdrive/MyDrive/sbs/핵심역량프로젝트/그래프/성인.csv')
old = pd.read_csv('/content/gdrive/MyDrive/sbs/핵심역량프로젝트/그래프/노인.csv')

# %%
# 심폐지구력 변화 비교(청소년.csv, 성인.csv, 노인.csv)

fig, ax = plt.subplots(1, 3, figsize=(28,8))
sns.set_style('whitegrid')
# palette = sns.color_palette('Set3')
# sns.set_palette('Set3')
# sns.set_palette(sns.color_palette(palette))

sns.barplot(x="측정년도", y='심폐지구력', hue="성별", data=teen, ax=ax[0], palette='seismic')
ax[0].set_title("심폐지구력 변화 : 청소년", y=1.04, size=18)

sns.barplot(x="측정년도", y='심폐지구력', hue="성별", data=adult, ax=ax[1], palette='seismic')
ax[1].set_title("심폐지구력 변화 : 성인", y=1.04, size=18)

sns.barplot(x="측정년도", y='심폐지구력', hue="성별", data=old, ax=ax[2], palette='seismic')
ax[2].set_title("심폐지구력 변화 : 노인", y=1.04, size=18)

for patch in ax[0].patches:
    ax[0].text(x = patch.get_x() + patch.get_width()/2, 
             y = patch.get_height() + len(teen_grip_graph)*0.2,
             s = f'{patch.get_height():.1f}회',
             ha = 'center')
    
for patch in ax[1].patches:
    ax[1].text(x = patch.get_x() + patch.get_width()/2, 
             y = patch.get_height() + len(adult_grip_graph)*0.2,
             s = f'{patch.get_height():.1f}회',
             ha = 'center')
    
for patch in ax[2].patches:
    ax[2].text(x = patch.get_x() + patch.get_width()/2, 
             y = patch.get_height() + len(old_grip_graph)*0.2,
             s = f'{patch.get_height():.1f}회',
             ha = 'center')

'''
for p in ax[0].patches:
    ax[0].annotate('%.1f 회' % p.get_height(), (p.get_x() + p.get_width()/2., p.get_height() - 30),
                ha='center', va='center', fontsize=12, color='black', xytext=(0,10), textcoords='offset points')
for p in ax[1].patches:
    ax[1].annotate('%.1f 회' % p.get_height(), (p.get_x() + p.get_width()/2., p.get_height() - 30),
                ha='center', va='center', fontsize=12, color='black', xytext=(0,10), textcoords='offset points')
for p in ax[2].patches:
    ax[2].annotate('%.1f 회' % p.get_height(), (p.get_x() + p.get_width()/2., p.get_height() - 30),
                ha='center', va='center', fontsize=12, color='black', xytext=(0,10), textcoords='offset points')
'''

# plt.xticks(fontsize=20)
# plt.savefig('심폐지구력 19-21 전후(청소년/성인/노인).png', bbox_inches='tight', pad_inches=0.5)
plt.show()

# %% [markdown]
# ## 8. 상위체력인구 비중 2019/2021 비교(연령대, 전체)

# %%
age_grade_df = pd.read_csv('/content/gdrive/MyDrive/sbs/핵심역량프로젝트/그래프/연령대별 상위체력인구 비중 변화.csv')
all_grade_df = pd.read_csv('/content/gdrive/MyDrive/sbs/핵심역량프로젝트/그래프/전체 상위체력인구 비중 변화.csv')

# %%
age_grade_df = age_grade_df.rename(index={0:2019, 1:2021})
all_grade_df = all_grade_df.rename(index={0:2019, 1:2021})

# %%
age_grade_df
# Out:
#       청소년   성인   노인
# 2019 0.36 0.41 0.49
# 2021 0.33 0.46 0.57

# %%
# 상위체력인구 비중(전체연령)
plt.figure(figsize=(20,20))
plt.style.use('ggplot')

plt.rc('font', size=25)        # 기본 폰트 크기
plt.rc('axes', labelsize=30)   # x,y축 label 폰트 크기
plt.rc('xtick', labelsize=20)  # x축 눈금 폰트 크기 
plt.rc('ytick', labelsize=20)  # y축 눈금 폰트 크기
plt.rc('figure', titlesize=20) # figure title 폰트 크기
plt.rc('legend', fontsize=14)  # 범례 폰트 크기

ax = all_grade_df.plot(kind='bar',  title="전체 연령대 상위체력인구 비중", rot=0, color=['skyblue'], figsize=(15,15))
ax.legend(all_grade_df.columns, loc='best')

for patch in ax.patches:
    ax.text(x = patch.get_x() + patch.get_width()/2, 
             y = patch.get_height() + len(age_grade_df)*0.001,
             s = f'{patch.get_height()*100:1.1f}%',
             ha = 'center')

plt.show()

# %%
# 상위체력인구 비중(연령대별)
plt.figure(figsize=(10,11))
plt.style.use('ggplot')

plt.rc('font', size=15)        # 기본 폰트 크기
plt.rc('axes', labelsize=30)   # x,y축 label 폰트 크기
plt.rc('xtick', labelsize=20)  # x축 눈금 폰트 크기 
plt.rc('ytick', labelsize=20)  # y축 눈금 폰트 크기
plt.rc('figure', titlesize=20) # figure title 폰트 크기

ax = age_grade_df.plot(kind='bar',  title="연령대별 상위체력인구 비중", rot=0, color=['#ff9999', '#ffc000', '#8fd9b6'], figsize=(10,11))
ax.legend(age_grade_df.columns, loc='best')

for patch in ax.patches:
    ax.text(x = patch.get_x() + patch.get_width()/2, 
             y = patch.get_height() + len(age_grade_df)*0.001,
             s = f'{patch.get_height()*100:1.1f}%',
             ha = 'center')

plt.show()

# %%
# 상위체력인구 비중(연령대별 상위체력인구 비중 변화.csv, 전체 상위체력인구 비중 변화.csv )

fig = plt.figure(figsize=(20,8))
plt.style.use('ggplot')
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

all_grade_df.plot(ax=ax1, kind='bar',  title="전체 연령대 상위체력인구 비중", rot=0, color=['skyblue'])
age_grade_df.plot(ax=ax2, kind='bar',  title="연령대별 상위체력인구 비중", rot=0, color=['#ff9999', '#ffc000', '#8fd9b6'])

ax1.legend(all_grade_df.columns, loc='best')
ax2.legend(age_grade_df.columns, loc='best')

for patch in ax1.patches:
    ax1.text(x = patch.get_x() + patch.get_width()/2, 
             y = patch.get_height() + len(age_grade_df)*0.001,
             s = f'{patch.get_height()*100:1.1f}%',
             ha = 'center')
    
for patch in ax2.patches:
    ax2.text(x = patch.get_x() + patch.get_width()/2, 
             y = patch.get_height() + len(all_grade_df)*0.001,
             s = f'{patch.get_height()*100:1.1f}%',
             ha = 'center')
    

'''
for p in ax1.patches:
    ax1.annotate('%.1f %%' % p.get_height(), (p.get_x() + p.get_width()/2., p.get_height() - 30),
                ha='center', va='center', fontsize=12, color='black', xytext=(0,10), textcoords='offset points')
    
for p in ax2.patches:
    ax2.annotate('%.1f %%' % p.get_height(), (p.get_x() + p.get_width()/2., p.get_height() - 30),
                ha='center', va='center', fontsize=12, color='black', xytext=(0,10), textcoords='offset points')
'''    

# plt.savefig('상위체력인구 비중.png', bbox_inches='tight', pad_inches=0.5)
plt.show()
